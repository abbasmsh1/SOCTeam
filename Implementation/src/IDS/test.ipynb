# %%
from preprocess import preprocess_data

# %%
df = preprocess_data(r"E:\IMT\2nd Sem\Project\Implementation\Data\NF-UQ-NIDS-v2.csv")
# Out:
# 📥 Loading data...
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = preprocess_data(r"E:\IMT\2nd Sem\Project\Implementation\Data\NF-UQ-NIDS-v2.csv")
#
# File e:\IMT\2nd Sem\Project\Implementation\src\IDS\preprocess.py:359, in preprocess_data(path, save_dir)
#     350 def preprocess_data(path: str, save_dir: Optional[str] = None) -> pd.DataFrame:
#     351     """
#     352     Preprocess data using the preprocessing pipeline.
#     353
#     354     Args:
#     355         path: Path to the CSV file
#     356         save_dir: Directory to save encoders and scaler (default: Models/)
#     357
#     358     Returns:
# --> 359         Preprocessed DataFrame
#     360     """
#     361     if save_dir is None:
#     362         save_dir = os.path.join(_BASE_DIR, "Models")
#
# ...

# %%
df
# Out:
#        src_port  dst_port  protocol  duration  packets_count  \
# 0      0.754949  0.006593       0.0  0.000021       0.000649
# 1      0.755499  0.006593       0.0  0.000003       0.000352
# 2      0.755270  0.001053       0.0  0.000413       0.000108
# 3      0.755774  0.006593       0.0  0.000007       0.000568
# 4      0.755728  0.006593       0.0  0.000008       0.000568
# ...         ...       ...       ...       ...            ...
# 45560  0.960191  0.006624       0.0  0.000048       0.000270
# 45561  0.764184  0.006593       0.0  0.000000       0.000000
# 45562  0.006426  0.763396       0.0  0.000000       0.000000
# 45563  0.488712  0.035285       0.0  0.000000       0.000000
# 45564  0.762871  0.006593       0.0  0.000000       0.000000
#
#        fwd_packets_count  bwd_packets_count  total_payload_bytes  \
# 0               0.000863           0.000578             0.000278
# 1               0.000628           0.000248             0.000052
# ...

# %%
df.describe()
# Out:
#            src_port      dst_port  protocol      duration  packets_count  \
# count  45565.000000  45565.000000   45565.0  4.556500e+04   45565.000000
# mean       0.612665      0.130136       0.0  2.438537e-03       0.000337
# std        0.277859      0.265916       0.0  1.565198e-02       0.005732
# min        0.000000      0.000000       0.0  0.000000e+00       0.000000
# 25%        0.598507      0.001053       0.0  2.877989e-10       0.000027
# 50%        0.685360      0.001053       0.0  2.085067e-06       0.000216
# 75%        0.793171      0.123148       0.0  3.673767e-04       0.000243
# max        1.000000      1.000000       0.0  1.000000e+00       1.000000
#
#        fwd_packets_count  bwd_packets_count  total_payload_bytes  \
# count       45565.000000       45565.000000         45565.000000
# mean            0.000540           0.000272             0.000157
# std             0.004935           0.006545             0.006550
# ...

# %%
df.fillna(0, inplace=True)
df.info()
df.isna().sum().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45565 entries, 0 to 45564
# Columns: 333 entries, src_port to second
# dtypes: float16(2), float64(330), int64(1)
# memory usage: 115.2 MB
# np.int64(0)
